# %% [markdown]
# # Data loading and visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
merged_df = pd.read_csv('data/cleaned/merged_df.csv')
display(merged_df.head())
print(merged_df.shape)
# Out:
#   State   County  Percent of Children with Confirmed BLLs ³5 µg/dL  \
# 0    AL  AUTAUGA                                               NaN
# 1    AL  BALDWIN                                               NaN
# 2    AL  BARBOUR                                               NaN
# 3    AL     BIBB                                               NaN
# 4    AL   BLOUNT                                               0.0
#
#    Built 2020 or later  Built 2000 to 2019  Built 1980 to 1999  \
# 0             0.018971            0.348779            0.233663
# 1             0.016696            0.460808            0.317366
# 2             0.000000            0.171020            0.400188
# 3             0.000000            0.269087            0.378022
# 4             0.003596            0.272173            0.367732
#
#    Built 1960 to 1979  Built 1940 to 1959  Built 1939 or earlier  \
# 0            0.310232            0.058325               0.030030
# 1            0.156746            0.030529               0.017855
# 2            0.253661            0.104736               0.070395
# 3            0.226947            0.060487               0.065456
# 4            0.221302            0.092610               0.042588
#
#    Lacking complete plumbing facilities  ...  \
# 0                                   0.5  ...
# 1                                   0.3  ...
# 2                                   0.2  ...
# 3                                   0.7  ...
# 4                                   0.6  ...
#
#    Income in the past 12 months at or above poverty level:!!18 to 64 years  \
# 0                                           0.567738
# 1                                           0.515682
# 2                                           0.491164
# 3                                           0.501439
# 4                                           0.532138
#
#    Income in the past 12 months at or above poverty level:!!65 years and over  \
# 0                                           0.151584
# 1                                           0.202625
# 2                                           0.187543
# 3                                           0.183021
# 4                                           0.165438
#
#        lat      lng  ADHD Percentage (Ever)  ADHD Percentage (Current)  \
# 0  32.5349 -86.6427                    12.7                       12.1
# 1  30.7277 -87.7226                    12.7                       12.1
# 2  31.8696 -85.3932                    12.7                       12.1
# 3  32.9986 -87.1265                    12.7                       12.1
# 4  33.9809 -86.5674                    12.7                       12.1
#
#    ADHD Behavior Treatment(%)  ADHD Medication(%)  ADHD Meds or BT  \
# 0                        50.6                77.0             84.3
# 1                        50.6                77.0             84.3
# 2                        50.6                77.0             84.3
# 3                        50.6                77.0             84.3
# 4                        50.6                77.0             84.3
#
#    Any Treatment
# 0           91.2
# 1           91.2
# 2           91.2
# 3           91.2
# 4           91.2
#
# [5 rows x 66 columns]
# (2151, 66)

# %%
# Visualizations
bll_column = 'Percent of Children with Confirmed BLLs ³5 µg/dL'
bll_stats = merged_df[bll_column].describe()
print(f"Descriptive Statistics for '{bll_column}':\n{bll_stats}")

plt.figure(figsize=(8, 6))
sns.histplot(merged_df[bll_column].dropna(), kde=True)
plt.title('Distribution of Percent of Children with Confirmed BLLs > 5 µg/dL')
plt.xlabel('Percent of Children')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(y=merged_df[bll_column])
plt.title('Boxplot of Percent of Children with Confirmed BLLs > 5 µg/dL')
plt.ylabel('Percent of Children')
plt.show()
# Out:
# Descriptive Statistics for 'Percent of Children with Confirmed BLLs ³5 µg/dL':
# count    1352.000000
# mean        1.282089
# std         2.204850
# min         0.000000
# 25%         0.000000
# 50%         0.565000
# 75%         1.700000
# max        39.000000
# Name: Percent of Children with Confirmed BLLs ³5 µg/dL, dtype: float64

# %% [markdown]
# # EDA

# %%
# Get indices of outliers
outlier_indices = merged_df[merged_df['County']=='UNKNOWN'].index
# Remove the outlier rows, store that result in filtered_df
filtered_df = merged_df.drop(index=outlier_indices)
print(filtered_df.shape)
# Out:
# (2124, 66)

# %%
# Correlation analysis and visualization
# Remove relevant columns
columns_to_exclude = ['State', 'County']
correlation_filtered_df = filtered_df.drop(columns=columns_to_exclude, errors="ignore")

# Define modified data frame
correlation_with_bll = correlation_filtered_df.corr().drop('Percent of Children with Confirmed BLLs ³5 µg/dL')

# Sort the correlations in descending order
sorted_correlations = correlation_with_bll['Percent of Children with Confirmed BLLs ³5 µg/dL'].sort_values(ascending=False)

# Print correlations
print(sorted_correlations)

# Visualize
plt.figure(figsize=(15, 20))
sns.heatmap(sorted_correlations.to_frame(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title(f"Correlation with filtered Percent of Children with Confirmed BLLs > 5 µg/dL")
plt.show()
# Out:
# Built 1939 or earlier              0.447773
# House Price$50,000 to $99,999      0.282895
# Built 1940 to 1959                 0.218774
# House Price$100,000 to $149,999    0.207115
# lat                                0.205219
#                                      ...
# ADHD Percentage (Current)         -0.217299
# ADHD Percentage (Ever)            -0.217862
# House Price$300,000 to $499,999   -0.218932
# Built 2000 to 2019                -0.299559
# Built 1980 to 1999                -0.337339
# Name: Percent of Children with Confirmed BLLs ³5 µg/dL, Length: 63, dtype: float64

# %%
# Determine number of missing values in filtered_df
missing_percentage = filtered_df[bll_column].isnull().sum() / len(filtered_df) * 100
print(f"Percentage of missing values in '{bll_column}': {missing_percentage:.2f}%")
# Out:
# Percentage of missing values in 'Percent of Children with Confirmed BLLs ³5 µg/dL': 37.43%

# %% [markdown]
# # Data cleaning for features

# %%
# Identify columns with missing values, excluding specified columns
cols_with_missing = [col for col in filtered_df.columns if filtered_df[col].isnull().any()
and col not in ['Percent of Children with Confirmed BLLs ³5 µg/dL']]

print(f"Number of feature columns with missing entries is :{len(cols_with_missing)}")
print(cols_with_missing)
# Out:
# Number of feature columns with missing entries is :57
# ['Built 2020 or later', 'Built 2000 to 2019', 'Built 1980 to 1999', 'Built 1960 to 1979', 'Built 1940 to 1959', 'Built 1939 or earlier', 'Lacking complete plumbing facilities', 'Lacking complete kitchen facilities', 'House PriceLess than $50,000', 'House Price$50,000 to $99,999', 'House Price$100,000 to $149,999', 'House Price$150,000 to $199,999', 'House Price$200,000 to $299,999', 'House Price$300,000 to $499,999', 'House Price$500,000 to $999,999', 'House Price$1,000,000 or more', 'Rent PriceLess than $500', 'Rent Price$500 to $999', 'Rent Price$1,000 to $1,499', 'Rent Price$1,500 to $1,999', 'Rent Price$2,000 to $2,499', 'Rent Price$2,500 to $2,999', 'Rent Price$3,000 or more', 'Owner occupied', 'Renter occupied', 'Under 19 years:!!With health insurance coverage', 'Under 19 years:!!No health insurance coverage', '19 to 64 years:!!With health insurance coverage', '19 to 64 years:!!No health insurance coverage', '65 years and over:!!With health insurance coverage', '65 years and over:!!No health insurance coverage', 'Agriculture, forestry, fishing and hunting, and mining', 'Construction', 'Manufacturing', 'Wholesale trade', 'Retail trade', 'Transportation and warehousing, and utilities', 'Information', 'Finance and insurance, and real estate and rental and leasing', 'Professional, scientific, and management, and administrative and waste management services', 'Educational services, and  health care and social assistance', 'Arts, entertainment, and recreation, and accommodation and food services', 'Other services, except public administration', 'Public administration', 'Management, business, science, and arts occupations', 'Service occupations', 'Sales and office occupations', 'Natural resources, construction, and maintenance occupations', 'Production, transportation, and material moving occupations', 'Income in the past 12 months below poverty level:!!Under 18 years', 'Income in the past 12 months below poverty level:!!18 to 64 years', 'Income in the past 12 months below poverty level:!!65 years and over', 'Income in the past 12 months at or above poverty level:!!Under 18 years', 'Income in the past 12 months at or above poverty level:!!18 to 64 years', 'Income in the past 12 months at or above poverty level:!!65 years and over', 'lat', 'lng']

# %%
# Impute missing values
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer(max_iter=10, random_state=42) #one can adjusts max_iter
imputer.fit(filtered_df[cols_with_missing])
imputed_data = imputer.transform(filtered_df[cols_with_missing])
filtered_df[cols_with_missing] = imputed_data

# %%
# Check to see if there are columns with missing values left
cols_with_missing = [col for col in filtered_df.columns if filtered_df[col].isnull().any()
and col not in ['Percent of Children with Confirmed BLLs ³5 µg/dL']]

print(f"Now the number of columns with missing value is: {len(cols_with_missing)}")
# Out:
# Now the number of columns with missing value is: 0

# %% [markdown]
# # Feature engineering

# %%
# Set a correlation threshold to remove features
corr_threshold = 0.02

# Use the previously calculated correlation_with_bll
# Get features with low correlation
low_corr_features = correlation_with_bll[
    abs(correlation_with_bll['Percent of Children with Confirmed BLLs ³5 µg/dL']) <= corr_threshold
].index.tolist()

# Print low_corr_features and their correlations for debugging
print("Low Correlation Features:")
for feature in low_corr_features:
    corr_value = correlation_with_bll.loc[feature, 'Percent of Children with Confirmed BLLs ³5 µg/dL']
    print(f"  {feature}: {corr_value}")

# Remove house price and rent price features and some more
cols_to_remove = list(set(low_corr_features + [ 
    'House PriceLess than $50,000',
    'House Price$50,000 to $99,999',
    'House Price$100,000 to $149,999',
    'House Price$150,000 to $199,999',
    'House Price$200,000 to $299,999',
    'House Price$300,000 to $499,999',
    'House Price$500,000 to $999,999',
    'House Price$1,000,000 or more',
    'Rent PriceLess than $500',
    'Rent Price$500 to $999',
    'Rent Price$1,000 to $1,499',
    'Rent Price$1,500 to $1,999',
    'Rent Price$2,000 to $2,499',
    'Rent Price$2,500 to $2,999',
    'Rent Price$3,000 or more',
]))

# Print cols_to_remove to verify features being dropped
print("\nColumns to Remove:")
print(cols_to_remove)
print(f"The number of feature columns we removed is: {len(cols_to_remove)}")
# Out:
# Low Correlation Features:
#   Lacking complete plumbing facilities: 0.019586263011316718
#   19 to 64 years:!!With health insurance coverage: 0.01607417277988455
#   19 to 64 years:!!No health insurance coverage: -0.015399603427433316
#   Public administration: -0.007885022356251303
#   Income in the past 12 months below poverty level:!!65 years and over: 0.0197779648255977
#   Any Treatment: 0.006804883056936159
#
# Columns to Remove:
# ['House PriceLess than $50,000', 'Lacking complete plumbing facilities', 'House Price$1,000,000 or more', 'Rent Price$3,000 or more', 'Rent Price$500 to $999', 'House Price$200,000 to $299,999', 'House Price$150,000 to $199,999', 'House Price$100,000 to $149,999', 'Rent Price$2,000 to $2,499', 'Income in the past 12 months below poverty level:!!65 years and over', 'House Price$50,000 to $99,999', 'Rent PriceLess than $500', 'Any Treatment', 'Rent Price$1,000 to $1,499', 'Public administration', '19 to 64 years:!!No health insurance coverage', 'Rent Price$2,500 to $2,999', '19 to 64 years:!!With health insurance coverage', 'House Price$300,000 to $499,999', 'House Price$500,000 to $999,999', 'Rent Price$1,500 to $1,999']
# The number of feature columns we removed is: 21

# %%
# Drop the columns from filtered_df
filtered_df = filtered_df.drop(columns=cols_to_remove, errors="ignore")
print(filtered_df.shape)
# Out:
# (2124, 45)

# %%
# Count non-null values in the target column
non_null_count = filtered_df['Percent of Children with Confirmed BLLs ³5 µg/dL'].notna().sum()

# Print the count
print(f"Number of rows with non-null percent bll values: {non_null_count}")
# Out:
# Number of rows with non-null percent bll values: 1329

# %% [markdown]
# # Data splitting

# %%
from sklearn.model_selection import train_test_split

# Remove 'State' and 'County'
new_df = filtered_df.drop(columns=['State', 'County'])
# Split data into training and prediction sets
df_train = new_df[filtered_df[bll_column].notnull()]
df_predict = new_df[filtered_df[bll_column].isnull()]

# Features (X) and target variable (y)
X_train = df_train.drop(columns=bll_column)
y_train = df_train[bll_column]
X_predict = df_predict.drop(columns=bll_column)

# Split training sets into 80/20
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("y_train shape:", y_train.shape)
print("y_val shape:", y_val.shape)
print("X_predict", X_predict.shape)
# Out:
# X_train shape: (1063, 42)
# X_val shape: (266, 42)
# y_train shape: (1063,)
# y_val shape: (266,)
# X_predict (795, 42)

# %%
print(X_train.shape)
# Out:
# (1063, 42)

# %%
# Scale ADHD columns to be over 1 instead of 100

adhd_cols = [col for col in X_train.columns if col.startswith('ADHD')]
if 'Any Treatment' not in cols_to_remove:  
    adhd_cols.append('Any Treatment')
    
for col in adhd_cols:
    X_train[col] = X_train[col] / 100 
    X_val[col] = X_val[col] / 100  
    X_predict[col] = X_predict[col] / 100

# %% [markdown]
# # Modeling with extra trees

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import randint, uniform

# Define Extra Trees Regressor
extra_trees_reg = ExtraTreesRegressor(random_state=42)

# Define a Refined Hyperparameter Search Space
param_distributions = {
    'n_estimators': randint(200, 500), 
    'max_depth': randint(10, 30),  
    'min_samples_split': randint(2, 10),  
    'min_samples_leaf': randint(1, 5),  
    'max_features': ['sqrt', 'log2', 0.5, 0.7, None],  
    'bootstrap': [True, False],
    'criterion': ['squared_error', 'absolute_error'],
    'ccp_alpha': uniform(0.0, 0.05)  
}

# Create RandomizedSearchCV
random_search_extra_trees = RandomizedSearchCV(
    estimator=extra_trees_reg,
    param_distributions=param_distributions,
    n_iter=100,  
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1,
    error_score='raise' 
)

# Fit the model using RandomizedSearchCV with Try-Except Block
try:
    random_search_extra_trees.fit(X_train, y_train)
except ValueError as e:
    print(f"Error during fit: {e}")

# Get the best parameters and best estimator
best_params_extra_trees = random_search_extra_trees.best_params_
best_extra_trees_reg = random_search_extra_trees.best_estimator_

# Make predictions and evaluate
y_pred_extra_trees = best_extra_trees_reg.predict(X_val)
mse_extra_trees = mean_squared_error(y_val, y_pred_extra_trees)
r2_extra_trees = r2_score(y_val, y_pred_extra_trees)
rmse_extra_trees = np.sqrt(mse_extra_trees)

print("Hyperparameter Tuned Extra Trees Regression Results:")
print(f"  Best Parameters: {best_params_extra_trees}")
print(f"  Root Mean Squared Error: {rmse_extra_trees}")
print(f"  R-squared: {r2_extra_trees}")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END bootstrap=True, ccp_alpha=0.039827149343011646, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=321; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.039827149343011646, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=321; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.004998745790900145, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=6, n_estimators=457; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.039827149343011646, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=321; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.039827149343011646, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=321; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.004998745790900145, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=6, n_estimators=457; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.004998745790900145, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=6, n_estimators=457; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.039827149343011646, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=8, n_estimators=321; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.004998745790900145, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=6, n_estimators=457; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.004998745790900145, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=6, n_estimators=457; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.02159725093210579, criterion=squared_error, max_depth=19, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=470; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.02159725093210579, criterion=squared_error, max_depth=19, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=470; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.02159725093210579, criterion=squared_error, max_depth=19, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=470; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.02159725093210579, criterion=squared_error, max_depth=19, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=470; total time=   0.7s
# [CV] END bootstrap=True, ccp_alpha=0.02159725093210579, criterion=squared_error, max_depth=19, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=470; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.04162213204002109, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=221; total time=  10.1s
# [CV] END bootstrap=False, ccp_alpha=0.04162213204002109, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=221; total time=  10.1s
# [CV] END bootstrap=False, ccp_alpha=0.04162213204002109, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=221; total time=  10.6s
# [CV] END bootstrap=False, ccp_alpha=0.04162213204002109, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=221; total time=  10.6s
# [CV] END bootstrap=False, ccp_alpha=0.04162213204002109, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=1, min_samples_split=2, n_estimators=221; total time=  10.7s
# [CV] END bootstrap=True, ccp_alpha=0.03037724259507192, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=213; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.03037724259507192, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=213; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.03037724259507192, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=213; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.03037724259507192, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=213; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.03037724259507192, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=213; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.00453032172664104, criterion=absolute_error, max_depth=28, max_features=0.7, min_samples_leaf=3, min_samples_split=5, n_estimators=330; total time=  13.4s
# [CV] END bootstrap=False, ccp_alpha=0.00453032172664104, criterion=absolute_error, max_depth=28, max_features=0.7, min_samples_leaf=3, min_samples_split=5, n_estimators=330; total time=  13.6s
# [CV] END bootstrap=False, ccp_alpha=0.00453032172664104, criterion=absolute_error, max_depth=28, max_features=0.7, min_samples_leaf=3, min_samples_split=5, n_estimators=330; total time=  13.3s
# [CV] END bootstrap=True, ccp_alpha=0.008668232675388604, criterion=squared_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=201; total time=   0.2s
# [CV] END bootstrap=True, ccp_alpha=0.008668232675388604, criterion=squared_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=201; total time=   0.2s
# [CV] END bootstrap=True, ccp_alpha=0.008668232675388604, criterion=squared_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=201; total time=   0.2s
# [CV] END bootstrap=True, ccp_alpha=0.008668232675388604, criterion=squared_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=201; total time=   0.2s
# [CV] END bootstrap=True, ccp_alpha=0.008668232675388604, criterion=squared_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=201; total time=   0.2s
# [CV] END bootstrap=False, ccp_alpha=0.00453032172664104, criterion=absolute_error, max_depth=28, max_features=0.7, min_samples_leaf=3, min_samples_split=5, n_estimators=330; total time=  11.7s
# [CV] END bootstrap=False, ccp_alpha=0.00453032172664104, criterion=absolute_error, max_depth=28, max_features=0.7, min_samples_leaf=3, min_samples_split=5, n_estimators=330; total time=  11.9s
# [CV] END bootstrap=False, ccp_alpha=0.019270825126995808, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=4, min_samples_split=8, n_estimators=463; total time=  13.5s
# [CV] END bootstrap=False, ccp_alpha=0.019270825126995808, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=4, min_samples_split=8, n_estimators=463; total time=  13.6s
# [CV] END bootstrap=False, ccp_alpha=0.019270825126995808, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=4, min_samples_split=8, n_estimators=463; total time=  13.9s
# [CV] END bootstrap=False, ccp_alpha=0.019270825126995808, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=4, min_samples_split=8, n_estimators=463; total time=  12.9s
# [CV] END bootstrap=False, ccp_alpha=0.019270825126995808, criterion=absolute_error, max_depth=11, max_features=0.7, min_samples_leaf=4, min_samples_split=8, n_estimators=463; total time=  13.1s
# [CV] END bootstrap=False, ccp_alpha=0.02600340105889054, criterion=absolute_error, max_depth=13, max_features=None, min_samples_leaf=3, min_samples_split=3, n_estimators=417; total time=  18.7s
# [CV] END bootstrap=False, ccp_alpha=0.02600340105889054, criterion=absolute_error, max_depth=13, max_features=None, min_samples_leaf=3, min_samples_split=3, n_estimators=417; total time=  18.4s
# [CV] END bootstrap=False, ccp_alpha=0.02600340105889054, criterion=absolute_error, max_depth=13, max_features=None, min_samples_leaf=3, min_samples_split=3, n_estimators=417; total time=  18.5s
# [CV] END bootstrap=False, ccp_alpha=0.02600340105889054, criterion=absolute_error, max_depth=13, max_features=None, min_samples_leaf=3, min_samples_split=3, n_estimators=417; total time=  18.2s
# [CV] END bootstrap=False, ccp_alpha=0.02600340105889054, criterion=absolute_error, max_depth=13, max_features=None, min_samples_leaf=3, min_samples_split=3, n_estimators=417; total time=  18.3s
# [CV] END bootstrap=False, ccp_alpha=0.046974947078209456, criterion=absolute_error, max_depth=13, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=495; total time=  20.8s
# [CV] END bootstrap=False, ccp_alpha=0.046974947078209456, criterion=absolute_error, max_depth=13, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=495; total time=  21.2s
# [CV] END bootstrap=True, ccp_alpha=0.019433864484474102, criterion=absolute_error, max_depth=24, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=416; total time=   9.1s
# [CV] END bootstrap=False, ccp_alpha=0.046974947078209456, criterion=absolute_error, max_depth=13, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=495; total time=  21.9s
# [CV] END bootstrap=False, ccp_alpha=0.030351712384334234, criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=264; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.030351712384334234, criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=264; total time=   0.9s
# [CV] END bootstrap=False, ccp_alpha=0.030351712384334234, criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=264; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.030351712384334234, criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=264; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.019433864484474102, criterion=absolute_error, max_depth=24, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=416; total time=   9.0s
# [CV] END bootstrap=False, ccp_alpha=0.030351712384334234, criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=264; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.019433864484474102, criterion=absolute_error, max_depth=24, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=416; total time=   9.1s
# [CV] END bootstrap=True, ccp_alpha=0.019433864484474102, criterion=absolute_error, max_depth=24, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=416; total time=   9.0s
# [CV] END bootstrap=True, ccp_alpha=0.049344346830025865, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=262; total time=   4.0s
# [CV] END bootstrap=False, ccp_alpha=0.046974947078209456, criterion=absolute_error, max_depth=13, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=495; total time=  20.3s
# [CV] END bootstrap=True, ccp_alpha=0.049344346830025865, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=262; total time=   3.8s
# [CV] END bootstrap=True, ccp_alpha=0.049344346830025865, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=262; total time=   3.8s
# [CV] END bootstrap=True, ccp_alpha=0.049344346830025865, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=262; total time=   3.7s
# [CV] END bootstrap=True, ccp_alpha=0.019433864484474102, criterion=absolute_error, max_depth=24, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=416; total time=   9.1s
# [CV] END bootstrap=False, ccp_alpha=0.017923286427213633, criterion=squared_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=232; total time=   0.2s
# [CV] END bootstrap=True, ccp_alpha=0.049344346830025865, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=4, min_samples_split=9, n_estimators=262; total time=   3.8s
# [CV] END bootstrap=False, ccp_alpha=0.017923286427213633, criterion=squared_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=232; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.017923286427213633, criterion=squared_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=232; total time=   0.2s
# [CV] END bootstrap=False, ccp_alpha=0.017923286427213633, criterion=squared_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=232; total time=   0.2s
# [CV] END bootstrap=False, ccp_alpha=0.017923286427213633, criterion=squared_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=232; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.046974947078209456, criterion=absolute_error, max_depth=13, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=495; total time=  21.1s
# [CV] END bootstrap=True, ccp_alpha=0.009942120204440259, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=460; total time=   8.2s
# [CV] END bootstrap=True, ccp_alpha=0.009942120204440259, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=460; total time=   8.2s
# [CV] END bootstrap=True, ccp_alpha=0.009942120204440259, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=460; total time=   8.2s
# [CV] END bootstrap=True, ccp_alpha=0.009942120204440259, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=460; total time=   8.1s
# [CV] END bootstrap=True, ccp_alpha=0.009942120204440259, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=460; total time=   8.4s
# [CV] END bootstrap=True, ccp_alpha=0.028062171292385057, criterion=squared_error, max_depth=14, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=417; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.028062171292385057, criterion=squared_error, max_depth=14, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=417; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.028062171292385057, criterion=squared_error, max_depth=14, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=417; total time=   0.7s
# [CV] END bootstrap=True, ccp_alpha=0.03854835899772805, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=378; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.028062171292385057, criterion=squared_error, max_depth=14, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=417; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.028062171292385057, criterion=squared_error, max_depth=14, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=417; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.03854835899772805, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=378; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.03854835899772805, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=378; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.03854835899772805, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=378; total time=   0.5s
# [CV] END bootstrap=True, ccp_alpha=0.03854835899772805, criterion=squared_error, max_depth=18, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=378; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.04478817978367597, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=421; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.04478817978367597, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=421; total time=   1.1s
# [CV] END bootstrap=True, ccp_alpha=0.04478817978367597, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=421; total time=   1.0s
# [CV] END bootstrap=True, ccp_alpha=0.012464611457443748, criterion=squared_error, max_depth=24, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=212; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.04478817978367597, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=421; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.012464611457443748, criterion=squared_error, max_depth=24, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=212; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.04478817978367597, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=421; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.012464611457443748, criterion=squared_error, max_depth=24, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=212; total time=   0.5s
# [CV] END bootstrap=True, ccp_alpha=0.012464611457443748, criterion=squared_error, max_depth=24, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=212; total time=   0.4s
# [CV] END bootstrap=False, ccp_alpha=0.018540912609913317, criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=413; total time=   9.4s
# [CV] END bootstrap=False, ccp_alpha=0.018540912609913317, criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=413; total time=   9.3s
# [CV] END bootstrap=True, ccp_alpha=0.012464611457443748, criterion=squared_error, max_depth=24, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=212; total time=   0.5s
# [CV] END bootstrap=False, ccp_alpha=0.0299432733244268, criterion=squared_error, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=333; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.0299432733244268, criterion=squared_error, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=333; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.0299432733244268, criterion=squared_error, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=333; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.0299432733244268, criterion=squared_error, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=333; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.0299432733244268, criterion=squared_error, max_depth=11, max_features=log2, min_samples_leaf=1, min_samples_split=7, n_estimators=333; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.018540912609913317, criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=413; total time=   9.0s
# [CV] END bootstrap=False, ccp_alpha=0.005502596226383838, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=397; total time=   1.8s
# [CV] END bootstrap=False, ccp_alpha=0.018540912609913317, criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=413; total time=   9.0s
# [CV] END bootstrap=False, ccp_alpha=0.018540912609913317, criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=413; total time=   8.9s
# [CV] END bootstrap=False, ccp_alpha=0.005502596226383838, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=397; total time=   1.7s
# [CV] END bootstrap=False, ccp_alpha=0.005502596226383838, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=397; total time=   1.7s
# [CV] END bootstrap=False, ccp_alpha=0.005502596226383838, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=397; total time=   1.8s
# [CV] END bootstrap=False, ccp_alpha=0.005502596226383838, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=4, n_estimators=397; total time=   1.9s
# [CV] END bootstrap=False, ccp_alpha=0.026704470968772098, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=371; total time=   3.7s
# [CV] END bootstrap=False, ccp_alpha=0.026704470968772098, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=371; total time=   3.7s
# [CV] END bootstrap=False, ccp_alpha=0.04018360384495573, criterion=absolute_error, max_depth=29, max_features=0.5, min_samples_leaf=4, min_samples_split=3, n_estimators=430; total time=   9.7s
# [CV] END bootstrap=False, ccp_alpha=0.04018360384495573, criterion=absolute_error, max_depth=29, max_features=0.5, min_samples_leaf=4, min_samples_split=3, n_estimators=430; total time=   9.6s
# [CV] END bootstrap=False, ccp_alpha=0.04018360384495573, criterion=absolute_error, max_depth=29, max_features=0.5, min_samples_leaf=4, min_samples_split=3, n_estimators=430; total time=   9.6s
# [CV] END bootstrap=False, ccp_alpha=0.04018360384495573, criterion=absolute_error, max_depth=29, max_features=0.5, min_samples_leaf=4, min_samples_split=3, n_estimators=430; total time=  10.0s
# [CV] END bootstrap=False, ccp_alpha=0.04018360384495573, criterion=absolute_error, max_depth=29, max_features=0.5, min_samples_leaf=4, min_samples_split=3, n_estimators=430; total time=  10.3s
# [CV] END bootstrap=False, ccp_alpha=0.026704470968772098, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=371; total time=   3.7s
# [CV] END bootstrap=False, ccp_alpha=0.026704470968772098, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=371; total time=   3.6s
# [CV] END bootstrap=False, ccp_alpha=0.026704470968772098, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=371; total time=   3.6s
# [CV] END bootstrap=False, ccp_alpha=0.01258911479126821, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=280; total time=   3.5s
# [CV] END bootstrap=False, ccp_alpha=0.01258911479126821, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=280; total time=   3.5s
# [CV] END bootstrap=False, ccp_alpha=0.01258911479126821, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=280; total time=   3.7s
# [CV] END bootstrap=False, ccp_alpha=0.01258911479126821, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=280; total time=   3.9s
# [CV] END bootstrap=True, ccp_alpha=0.030478216698994844, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=325; total time=   2.8s
# [CV] END bootstrap=False, ccp_alpha=0.01258911479126821, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=280; total time=   3.9s
# [CV] END bootstrap=True, ccp_alpha=0.030478216698994844, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=325; total time=   2.7s
# [CV] END bootstrap=False, ccp_alpha=0.04714548519562596, criterion=absolute_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=251; total time=  12.2s
# [CV] END bootstrap=False, ccp_alpha=0.04714548519562596, criterion=absolute_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=251; total time=  12.1s
# [CV] END bootstrap=False, ccp_alpha=0.04714548519562596, criterion=absolute_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=251; total time=  12.4s
# [CV] END bootstrap=True, ccp_alpha=0.030478216698994844, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=325; total time=   2.5s
# [CV] END bootstrap=False, ccp_alpha=0.04714548519562596, criterion=absolute_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=251; total time=  12.5s
# [CV] END bootstrap=False, ccp_alpha=0.04714548519562596, criterion=absolute_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=7, n_estimators=251; total time=  12.4s
# [CV] END bootstrap=True, ccp_alpha=0.030478216698994844, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=325; total time=   2.6s
# [CV] END bootstrap=True, ccp_alpha=0.030478216698994844, criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=325; total time=   2.5s
# [CV] END bootstrap=True, ccp_alpha=0.012107996913871294, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=2, min_samples_split=7, n_estimators=439; total time=   9.3s
# [CV] END bootstrap=True, ccp_alpha=0.012107996913871294, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=2, min_samples_split=7, n_estimators=439; total time=   9.3s
# [CV] END bootstrap=True, ccp_alpha=0.012107996913871294, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=2, min_samples_split=7, n_estimators=439; total time=   9.1s
# [CV] END bootstrap=False, ccp_alpha=0.02654672916585682, criterion=absolute_error, max_depth=15, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=383; total time=  12.7s
# [CV] END bootstrap=False, ccp_alpha=0.02654672916585682, criterion=absolute_error, max_depth=15, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=383; total time=  13.2s
# [CV] END bootstrap=False, ccp_alpha=0.02654672916585682, criterion=absolute_error, max_depth=15, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=383; total time=  13.0s
# [CV] END bootstrap=False, ccp_alpha=0.02654672916585682, criterion=absolute_error, max_depth=15, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=383; total time=  13.2s
# [CV] END bootstrap=False, ccp_alpha=0.02654672916585682, criterion=absolute_error, max_depth=15, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=383; total time=  13.1s
# [CV] END bootstrap=True, ccp_alpha=0.011012052378277416, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=398; total time=   4.9s
# [CV] END bootstrap=True, ccp_alpha=0.012107996913871294, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=2, min_samples_split=7, n_estimators=439; total time=   8.9s
# [CV] END bootstrap=True, ccp_alpha=0.012107996913871294, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=2, min_samples_split=7, n_estimators=439; total time=   9.2s
# [CV] END bootstrap=True, ccp_alpha=0.011012052378277416, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=398; total time=   5.2s
# [CV] END bootstrap=True, ccp_alpha=0.011012052378277416, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=398; total time=   5.1s
# [CV] END bootstrap=True, ccp_alpha=0.011012052378277416, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=398; total time=   4.9s
# [CV] END bootstrap=False, ccp_alpha=0.0470261632244802, criterion=absolute_error, max_depth=16, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=466; total time=   4.3s
# [CV] END bootstrap=True, ccp_alpha=0.011012052378277416, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=4, min_samples_split=9, n_estimators=398; total time=   4.7s
# [CV] END bootstrap=False, ccp_alpha=0.0470261632244802, criterion=absolute_error, max_depth=16, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=466; total time=   4.4s
# [CV] END bootstrap=False, ccp_alpha=0.0417651247794619, criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=  22.0s
# [CV] END bootstrap=False, ccp_alpha=0.0470261632244802, criterion=absolute_error, max_depth=16, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=466; total time=   4.2s
# [CV] END bootstrap=False, ccp_alpha=0.0470261632244802, criterion=absolute_error, max_depth=16, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=466; total time=   4.3s
# [CV] END bootstrap=False, ccp_alpha=0.0470261632244802, criterion=absolute_error, max_depth=16, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=466; total time=   4.1s
# [CV] END bootstrap=False, ccp_alpha=0.0417651247794619, criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=  21.2s
# [CV] END bootstrap=False, ccp_alpha=0.0417651247794619, criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=  21.7s
# [CV] END bootstrap=False, ccp_alpha=0.0417651247794619, criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=  21.9s
# [CV] END bootstrap=False, ccp_alpha=0.0417651247794619, criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=  22.2s
# [CV] END bootstrap=False, ccp_alpha=0.04910841716647178, criterion=absolute_error, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=453; total time=   5.8s[CV] END bootstrap=False, ccp_alpha=0.04910841716647178, criterion=absolute_error, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=453; total time=   5.8s
#
# [CV] END bootstrap=False, ccp_alpha=0.04910841716647178, criterion=absolute_error, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=453; total time=   5.9s
# [CV] END bootstrap=False, ccp_alpha=0.03676080596203861, criterion=absolute_error, max_depth=19, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=343; total time=   8.9s
# [CV] END bootstrap=False, ccp_alpha=0.03676080596203861, criterion=absolute_error, max_depth=19, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=343; total time=   8.8s
# [CV] END bootstrap=False, ccp_alpha=0.03676080596203861, criterion=absolute_error, max_depth=19, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=343; total time=   8.9s
# [CV] END bootstrap=False, ccp_alpha=0.03676080596203861, criterion=absolute_error, max_depth=19, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=343; total time=   8.6s
# [CV] END bootstrap=False, ccp_alpha=0.03676080596203861, criterion=absolute_error, max_depth=19, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=343; total time=   8.8s
# [CV] END bootstrap=False, ccp_alpha=0.02791467268035488, criterion=absolute_error, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=407; total time=   4.4s
# [CV] END bootstrap=False, ccp_alpha=0.02791467268035488, criterion=absolute_error, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=407; total time=   4.1s
# [CV] END bootstrap=False, ccp_alpha=0.02791467268035488, criterion=absolute_error, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=407; total time=   4.3s
# [CV] END bootstrap=False, ccp_alpha=0.02791467268035488, criterion=absolute_error, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=407; total time=   4.3s
# [CV] END bootstrap=False, ccp_alpha=0.02791467268035488, criterion=absolute_error, max_depth=18, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=407; total time=   4.4s
# [CV] END bootstrap=False, ccp_alpha=0.04910841716647178, criterion=absolute_error, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=453; total time=   5.6s
# [CV] END bootstrap=False, ccp_alpha=0.04910841716647178, criterion=absolute_error, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=453; total time=   5.9s
# [CV] END bootstrap=True, ccp_alpha=0.042816214593904625, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=2, n_estimators=303; total time=   5.3s
# [CV] END bootstrap=True, ccp_alpha=0.042816214593904625, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=2, n_estimators=303; total time=   5.0s
# [CV] END bootstrap=True, ccp_alpha=0.042816214593904625, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=2, n_estimators=303; total time=   5.0s
# [CV] END bootstrap=False, ccp_alpha=0.029034331071822735, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=393; total time=   4.8s
# [CV] END bootstrap=True, ccp_alpha=0.042816214593904625, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=2, n_estimators=303; total time=   5.1s
# [CV] END bootstrap=True, ccp_alpha=0.042816214593904625, criterion=absolute_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=2, n_estimators=303; total time=   5.1s
# [CV] END bootstrap=False, ccp_alpha=0.029034331071822735, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=393; total time=   5.1s
# [CV] END bootstrap=False, ccp_alpha=0.029034331071822735, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=393; total time=   4.9s
# [CV] END bootstrap=False, ccp_alpha=0.022421207149312367, criterion=squared_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=488; total time=   1.6s
# [CV] END bootstrap=False, ccp_alpha=0.022421207149312367, criterion=squared_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=488; total time=   1.5s
# [CV] END bootstrap=False, ccp_alpha=0.022421207149312367, criterion=squared_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=488; total time=   1.5s
# [CV] END bootstrap=False, ccp_alpha=0.022421207149312367, criterion=squared_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=488; total time=   1.5s
# [CV] END bootstrap=False, ccp_alpha=0.022421207149312367, criterion=squared_error, max_depth=18, max_features=0.7, min_samples_leaf=1, min_samples_split=5, n_estimators=488; total time=   1.6s
# [CV] END bootstrap=False, ccp_alpha=0.029034331071822735, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=393; total time=   4.9s
# [CV] END bootstrap=False, ccp_alpha=0.004683738391404624, criterion=squared_error, max_depth=23, max_features=None, min_samples_leaf=3, min_samples_split=7, n_estimators=463; total time=   1.4s
# [CV] END bootstrap=False, ccp_alpha=0.004683738391404624, criterion=squared_error, max_depth=23, max_features=None, min_samples_leaf=3, min_samples_split=7, n_estimators=463; total time=   1.4s
# [CV] END bootstrap=False, ccp_alpha=0.029034331071822735, criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=393; total time=   4.9s
# [CV] END bootstrap=False, ccp_alpha=0.004683738391404624, criterion=squared_error, max_depth=23, max_features=None, min_samples_leaf=3, min_samples_split=7, n_estimators=463; total time=   1.4s
# [CV] END bootstrap=False, ccp_alpha=0.004683738391404624, criterion=squared_error, max_depth=23, max_features=None, min_samples_leaf=3, min_samples_split=7, n_estimators=463; total time=   1.5s
# [CV] END bootstrap=True, ccp_alpha=0.021719718275521434, criterion=squared_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=9, n_estimators=346; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.004683738391404624, criterion=squared_error, max_depth=23, max_features=None, min_samples_leaf=3, min_samples_split=7, n_estimators=463; total time=   1.5s
# [CV] END bootstrap=True, ccp_alpha=0.021719718275521434, criterion=squared_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=9, n_estimators=346; total time=   0.6s
# [CV] END bootstrap=True, ccp_alpha=0.021719718275521434, criterion=squared_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=9, n_estimators=346; total time=   0.6s
# [CV] END bootstrap=True, ccp_alpha=0.021719718275521434, criterion=squared_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=9, n_estimators=346; total time=   0.6s
# [CV] END bootstrap=True, ccp_alpha=0.021719718275521434, criterion=squared_error, max_depth=10, max_features=0.7, min_samples_leaf=3, min_samples_split=9, n_estimators=346; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.001215798321572692, criterion=squared_error, max_depth=26, max_features=0.7, min_samples_leaf=4, min_samples_split=7, n_estimators=245; total time=   0.5s
# [CV] END bootstrap=False, ccp_alpha=0.001215798321572692, criterion=squared_error, max_depth=26, max_features=0.7, min_samples_leaf=4, min_samples_split=7, n_estimators=245; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.001215798321572692, criterion=squared_error, max_depth=26, max_features=0.7, min_samples_leaf=4, min_samples_split=7, n_estimators=245; total time=   0.5s
# [CV] END bootstrap=False, ccp_alpha=0.001215798321572692, criterion=squared_error, max_depth=26, max_features=0.7, min_samples_leaf=4, min_samples_split=7, n_estimators=245; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.001215798321572692, criterion=squared_error, max_depth=26, max_features=0.7, min_samples_leaf=4, min_samples_split=7, n_estimators=245; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.016269984907963386, criterion=absolute_error, max_depth=17, max_features=0.5, min_samples_leaf=1, min_samples_split=9, n_estimators=232; total time=   8.0s
# [CV] END bootstrap=False, ccp_alpha=0.016269984907963386, criterion=absolute_error, max_depth=17, max_features=0.5, min_samples_leaf=1, min_samples_split=9, n_estimators=232; total time=   8.0s
# [CV] END bootstrap=False, ccp_alpha=0.016269984907963386, criterion=absolute_error, max_depth=17, max_features=0.5, min_samples_leaf=1, min_samples_split=9, n_estimators=232; total time=   7.9s
# [CV] END bootstrap=False, ccp_alpha=0.016269984907963386, criterion=absolute_error, max_depth=17, max_features=0.5, min_samples_leaf=1, min_samples_split=9, n_estimators=232; total time=   7.9s
# [CV] END bootstrap=False, ccp_alpha=0.016269984907963386, criterion=absolute_error, max_depth=17, max_features=0.5, min_samples_leaf=1, min_samples_split=9, n_estimators=232; total time=   8.2s
# [CV] END bootstrap=True, ccp_alpha=0.04818099885446264, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=360; total time=   1.0s
# [CV] END bootstrap=True, ccp_alpha=0.04818099885446264, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=360; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.04818099885446264, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=360; total time=   1.0s
# [CV] END bootstrap=True, ccp_alpha=0.04818099885446264, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=360; total time=   1.0s
# [CV] END bootstrap=True, ccp_alpha=0.04818099885446264, criterion=squared_error, max_depth=29, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=360; total time=   0.9s
# [CV] END bootstrap=False, ccp_alpha=0.024263993713815785, criterion=absolute_error, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=373; total time=   3.6s
# [CV] END bootstrap=False, ccp_alpha=0.024263993713815785, criterion=absolute_error, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=373; total time=   3.5s
# [CV] END bootstrap=False, ccp_alpha=0.024263993713815785, criterion=absolute_error, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=373; total time=   3.5s
# [CV] END bootstrap=True, ccp_alpha=0.04417470111331295, criterion=absolute_error, max_depth=18, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=380; total time=   8.2s
# [CV] END bootstrap=False, ccp_alpha=0.01044593588076801, criterion=squared_error, max_depth=11, max_features=0.5, min_samples_leaf=2, min_samples_split=3, n_estimators=472; total time=   1.0s
# [CV] END bootstrap=True, ccp_alpha=0.04417470111331295, criterion=absolute_error, max_depth=18, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=380; total time=   8.6s
# [CV] END bootstrap=True, ccp_alpha=0.04417470111331295, criterion=absolute_error, max_depth=18, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=380; total time=   8.4s
# [CV] END bootstrap=False, ccp_alpha=0.01044593588076801, criterion=squared_error, max_depth=11, max_features=0.5, min_samples_leaf=2, min_samples_split=3, n_estimators=472; total time=   0.9s
# [CV] END bootstrap=False, ccp_alpha=0.01044593588076801, criterion=squared_error, max_depth=11, max_features=0.5, min_samples_leaf=2, min_samples_split=3, n_estimators=472; total time=   1.0s
# [CV] END bootstrap=False, ccp_alpha=0.01044593588076801, criterion=squared_error, max_depth=11, max_features=0.5, min_samples_leaf=2, min_samples_split=3, n_estimators=472; total time=   1.0s
# [CV] END bootstrap=False, ccp_alpha=0.0348507870497634, criterion=squared_error, max_depth=25, max_features=None, min_samples_leaf=2, min_samples_split=8, n_estimators=225; total time=   0.7s
# [CV] END bootstrap=False, ccp_alpha=0.01044593588076801, criterion=squared_error, max_depth=11, max_features=0.5, min_samples_leaf=2, min_samples_split=3, n_estimators=472; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.04417470111331295, criterion=absolute_error, max_depth=18, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=380; total time=   8.3s
# [CV] END bootstrap=True, ccp_alpha=0.04417470111331295, criterion=absolute_error, max_depth=18, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=380; total time=   8.2s
# [CV] END bootstrap=False, ccp_alpha=0.0348507870497634, criterion=squared_error, max_depth=25, max_features=None, min_samples_leaf=2, min_samples_split=8, n_estimators=225; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.024263993713815785, criterion=absolute_error, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=373; total time=   3.4s
# [CV] END bootstrap=False, ccp_alpha=0.0348507870497634, criterion=squared_error, max_depth=25, max_features=None, min_samples_leaf=2, min_samples_split=8, n_estimators=225; total time=   0.7s
# [CV] END bootstrap=False, ccp_alpha=0.0348507870497634, criterion=squared_error, max_depth=25, max_features=None, min_samples_leaf=2, min_samples_split=8, n_estimators=225; total time=   0.7s
# [CV] END bootstrap=False, ccp_alpha=0.0348507870497634, criterion=squared_error, max_depth=25, max_features=None, min_samples_leaf=2, min_samples_split=8, n_estimators=225; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.024263993713815785, criterion=absolute_error, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=9, n_estimators=373; total time=   3.4s
# [CV] END bootstrap=True, ccp_alpha=0.012810347179722903, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=2, min_samples_split=8, n_estimators=235; total time=   5.0s
# [CV] END bootstrap=True, ccp_alpha=0.012810347179722903, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=2, min_samples_split=8, n_estimators=235; total time=   4.9s
# [CV] END bootstrap=True, ccp_alpha=0.012810347179722903, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=2, min_samples_split=8, n_estimators=235; total time=   4.9s
# [CV] END bootstrap=True, ccp_alpha=0.012810347179722903, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=2, min_samples_split=8, n_estimators=235; total time=   5.1s
# [CV] END bootstrap=True, ccp_alpha=0.012810347179722903, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=2, min_samples_split=8, n_estimators=235; total time=   4.9s
# [CV] END bootstrap=True, ccp_alpha=0.009713697675602113, criterion=absolute_error, max_depth=23, max_features=0.7, min_samples_leaf=3, min_samples_split=8, n_estimators=342; total time=   6.2s
# [CV] END bootstrap=True, ccp_alpha=0.009713697675602113, criterion=absolute_error, max_depth=23, max_features=0.7, min_samples_leaf=3, min_samples_split=8, n_estimators=342; total time=   6.3s
# [CV] END bootstrap=True, ccp_alpha=0.009713697675602113, criterion=absolute_error, max_depth=23, max_features=0.7, min_samples_leaf=3, min_samples_split=8, n_estimators=342; total time=   6.1s
# [CV] END bootstrap=False, ccp_alpha=0.028943244775377935, criterion=absolute_error, max_depth=28, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=389; total time=   4.6s
# [CV] END bootstrap=False, ccp_alpha=0.028943244775377935, criterion=absolute_error, max_depth=28, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=389; total time=   4.7s
# [CV] END bootstrap=False, ccp_alpha=0.028943244775377935, criterion=absolute_error, max_depth=28, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=389; total time=   4.6s
# [CV] END bootstrap=True, ccp_alpha=0.009713697675602113, criterion=absolute_error, max_depth=23, max_features=0.7, min_samples_leaf=3, min_samples_split=8, n_estimators=342; total time=   6.0s
# [CV] END bootstrap=True, ccp_alpha=0.009713697675602113, criterion=absolute_error, max_depth=23, max_features=0.7, min_samples_leaf=3, min_samples_split=8, n_estimators=342; total time=   6.3s
# ...
# [CV] END bootstrap=True, ccp_alpha=0.012684108693656937, criterion=absolute_error, max_depth=29, max_features=0.7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, ccp_alpha=0.029168438254857983, criterion=absolute_error, max_depth=26, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=316; total time=   1.6s
# [CV] END bootstrap=False, ccp_alpha=0.040105462451336706, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=279; total time=   0.9s
# [CV] END bootstrap=False, ccp_alpha=0.040105462451336706, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=279; total time=   0.9s
# [CV] END bootstrap=False, ccp_alpha=0.040105462451336706, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=6, n_estimators=279; total time=   0.9s
# [CV] END bootstrap=True, ccp_alpha=0.026154892208507443, criterion=squared_error, max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=458; total time=   0.6s
# [CV] END bootstrap=True, ccp_alpha=0.026154892208507443, criterion=squared_error, max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=458; total time=   0.5s
# [CV] END bootstrap=True, ccp_alpha=0.026154892208507443, criterion=squared_error, max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=458; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.036855035292150964, criterion=squared_error, max_depth=21, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=   0.3s
# [CV] END bootstrap=True, ccp_alpha=0.026154892208507443, criterion=squared_error, max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=458; total time=   0.6s
# [CV] END bootstrap=True, ccp_alpha=0.026154892208507443, criterion=squared_error, max_depth=26, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=458; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.036855035292150964, criterion=squared_error, max_depth=21, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.036855035292150964, criterion=squared_error, max_depth=21, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.036855035292150964, criterion=squared_error, max_depth=21, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.036855035292150964, criterion=squared_error, max_depth=21, max_features=log2, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=   0.4s
# [CV] END bootstrap=True, ccp_alpha=0.013869059149056635, criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=377; total time=   1.7s
# [CV] END bootstrap=True, ccp_alpha=0.013869059149056635, criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=377; total time=   2.0s
# [CV] END bootstrap=True, ccp_alpha=0.013869059149056635, criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=377; total time=   1.7s
# [CV] END bootstrap=False, ccp_alpha=0.003886731848249242, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.003886731848249242, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   0.6s
# [CV] END bootstrap=True, ccp_alpha=0.013869059149056635, criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=377; total time=   1.7s
# [CV] END bootstrap=True, ccp_alpha=0.013869059149056635, criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=4, min_samples_split=3, n_estimators=377; total time=   1.7s
# [CV] END bootstrap=False, ccp_alpha=0.003886731848249242, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.003886731848249242, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   0.7s
# [CV] END bootstrap=False, ccp_alpha=0.003886731848249242, criterion=squared_error, max_depth=13, max_features=0.5, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   0.6s
# [CV] END bootstrap=False, ccp_alpha=0.046232166511179805, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=219; total time=   6.9s
# [CV] END bootstrap=False, ccp_alpha=0.046232166511179805, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=219; total time=   7.0s
# [CV] END bootstrap=False, ccp_alpha=0.046232166511179805, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=219; total time=   7.1s
# [CV] END bootstrap=False, ccp_alpha=0.046232166511179805, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=219; total time=   7.0s
# [CV] END bootstrap=False, ccp_alpha=0.046232166511179805, criterion=absolute_error, max_depth=14, max_features=0.7, min_samples_leaf=3, min_samples_split=4, n_estimators=219; total time=   6.9s
# [CV] END bootstrap=True, ccp_alpha=0.015476380814316388, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=4, min_samples_split=6, n_estimators=245; total time=   3.9s
# [CV] END bootstrap=True, ccp_alpha=0.015476380814316388, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=4, min_samples_split=6, n_estimators=245; total time=   3.9s
# [CV] END bootstrap=True, ccp_alpha=0.015476380814316388, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=4, min_samples_split=6, n_estimators=245; total time=   3.8s
# [CV] END bootstrap=True, ccp_alpha=0.015476380814316388, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=4, min_samples_split=6, n_estimators=245; total time=   3.9s
# [CV] END bootstrap=True, ccp_alpha=0.015476380814316388, criterion=absolute_error, max_depth=22, max_features=0.7, min_samples_leaf=4, min_samples_split=6, n_estimators=245; total time=   4.0s
# [CV] END bootstrap=False, ccp_alpha=0.04383307429628964, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=9, n_estimators=488; total time=   1.4s
# [CV] END bootstrap=False, ccp_alpha=0.04383307429628964, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=9, n_estimators=488; total time=   1.4s
# [CV] END bootstrap=True, ccp_alpha=0.041126862146158454, criterion=absolute_error, max_depth=28, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=209; total time=   5.2s
# [CV] END bootstrap=True, ccp_alpha=0.041126862146158454, criterion=absolute_error, max_depth=28, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=209; total time=   5.2s
# [CV] END bootstrap=False, ccp_alpha=0.04383307429628964, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=9, n_estimators=488; total time=   1.3s
# [CV] END bootstrap=True, ccp_alpha=0.041126862146158454, criterion=absolute_error, max_depth=28, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=209; total time=   5.4s
# [CV] END bootstrap=False, ccp_alpha=0.04383307429628964, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=9, n_estimators=488; total time=   1.4s
# [CV] END bootstrap=False, ccp_alpha=0.04383307429628964, criterion=squared_error, max_depth=22, max_features=None, min_samples_leaf=3, min_samples_split=9, n_estimators=488; total time=   1.4s
# [CV] END bootstrap=True, ccp_alpha=0.019649472448942957, criterion=squared_error, max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=304; total time=   1.1s
# [CV] END bootstrap=True, ccp_alpha=0.041126862146158454, criterion=absolute_error, max_depth=28, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=209; total time=   4.9s
# [CV] END bootstrap=True, ccp_alpha=0.041126862146158454, criterion=absolute_error, max_depth=28, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=209; total time=   5.2s
# [CV] END bootstrap=True, ccp_alpha=0.019649472448942957, criterion=squared_error, max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=304; total time=   1.1s
# [CV] END bootstrap=True, ccp_alpha=0.019649472448942957, criterion=squared_error, max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=304; total time=   1.1s
# [CV] END bootstrap=True, ccp_alpha=0.019649472448942957, criterion=squared_error, max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=304; total time=   1.1s
# [CV] END bootstrap=True, ccp_alpha=0.00669260594003166, criterion=squared_error, max_depth=25, max_features=0.7, min_samples_leaf=1, min_samples_split=6, n_estimators=332; total time=   0.8s
# [CV] END bootstrap=True, ccp_alpha=0.019649472448942957, criterion=squared_error, max_depth=26, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=304; total time=   1.2s
# [CV] END bootstrap=True, ccp_alpha=0.00669260594003166, criterion=squared_error, max_depth=25, max_features=0.7, min_samples_leaf=1, min_samples_split=6, n_estimators=332; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.04052766653909165, criterion=absolute_error, max_depth=24, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=481; total time=   5.0s
# [CV] END bootstrap=True, ccp_alpha=0.00669260594003166, criterion=squared_error, max_depth=25, max_features=0.7, min_samples_leaf=1, min_samples_split=6, n_estimators=332; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.04052766653909165, criterion=absolute_error, max_depth=24, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=481; total time=   5.0s
# [CV] END bootstrap=False, ccp_alpha=0.04052766653909165, criterion=absolute_error, max_depth=24, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=481; total time=   4.9s
# [CV] END bootstrap=True, ccp_alpha=0.00669260594003166, criterion=squared_error, max_depth=25, max_features=0.7, min_samples_leaf=1, min_samples_split=6, n_estimators=332; total time=   0.8s
# [CV] END bootstrap=False, ccp_alpha=0.04052766653909165, criterion=absolute_error, max_depth=24, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=481; total time=   5.1s
# [CV] END bootstrap=True, ccp_alpha=0.00669260594003166, criterion=squared_error, max_depth=25, max_features=0.7, min_samples_leaf=1, min_samples_split=6, n_estimators=332; total time=   0.9s
# [CV] END bootstrap=False, ccp_alpha=0.04052766653909165, criterion=absolute_error, max_depth=24, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=481; total time=   5.1s
# [CV] END bootstrap=True, ccp_alpha=0.012054241616481593, criterion=squared_error, max_depth=23, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=404; total time=   0.5s
# [CV] END bootstrap=True, ccp_alpha=0.012054241616481593, criterion=squared_error, max_depth=23, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=404; total time=   0.5s
# [CV] END bootstrap=True, ccp_alpha=0.012054241616481593, criterion=squared_error, max_depth=23, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=404; total time=   0.5s
# [CV] END bootstrap=True, ccp_alpha=0.012054241616481593, criterion=squared_error, max_depth=23, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=404; total time=   0.4s
# [CV] END bootstrap=False, ccp_alpha=0.04565828761288215, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=282; total time=   1.2s
# [CV] END bootstrap=False, ccp_alpha=0.04565828761288215, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=282; total time=   1.3s
# [CV] END bootstrap=False, ccp_alpha=0.04565828761288215, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=282; total time=   1.3s
# [CV] END bootstrap=False, ccp_alpha=0.04565828761288215, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=282; total time=   1.3s
# [CV] END bootstrap=False, ccp_alpha=0.011432140275173136, criterion=squared_error, max_depth=17, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=271; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.011432140275173136, criterion=squared_error, max_depth=17, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=271; total time=   0.3s
# [CV] END bootstrap=False, ccp_alpha=0.04565828761288215, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=282; total time=   1.3s
# [CV] END bootstrap=False, ccp_alpha=0.011432140275173136, criterion=squared_error, max_depth=17, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=271; total time=   0.2s
# [CV] END bootstrap=True, ccp_alpha=0.012054241616481593, criterion=squared_error, max_depth=23, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=404; total time=   0.5s
# [CV] END bootstrap=False, ccp_alpha=0.011432140275173136, criterion=squared_error, max_depth=17, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=271; total time=   0.2s
# [CV] END bootstrap=False, ccp_alpha=0.011432140275173136, criterion=squared_error, max_depth=17, max_features=log2, min_samples_leaf=4, min_samples_split=8, n_estimators=271; total time=   0.3s
# [CV] END bootstrap=True, ccp_alpha=0.03357865977963998, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=253; total time=   3.1s
# [CV] END bootstrap=True, ccp_alpha=0.03357865977963998, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=253; total time=   3.1s
# [CV] END bootstrap=True, ccp_alpha=0.03357865977963998, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=253; total time=   3.1s
# [CV] END bootstrap=True, ccp_alpha=0.03357865977963998, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=253; total time=   3.1s
# [CV] END bootstrap=True, ccp_alpha=0.03357865977963998, criterion=absolute_error, max_depth=12, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=253; total time=   3.0s
# Hyperparameter Tuned Extra Trees Regression Results:
#   Best Parameters: {'bootstrap': False, 'ccp_alpha': np.float64(0.001215798321572692), 'criterion': 'squared_error', 'max_depth': 26, 'max_features': 0.7, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 245}
#   Root Mean Squared Error: 1.722877444192325
#   R-squared: 0.378652742491453

# %%
# Get feature importance
feature_importance_extra_trees = best_extra_trees_reg.feature_importances_

# Create df for feature importance
feature_importance_extra_trees_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance_extra_trees
})

# Sort by importance
feature_importance_extra_trees_df = feature_importance_extra_trees_df.sort_values(by='Importance', ascending=False)

# Select top 10 features
top_10_features_extra_trees = feature_importance_extra_trees_df['Feature'].head(10).tolist()

# Print feature names and indices for verification
for feature in top_10_features_extra_trees:
    feature_index = X_train.columns.get_loc(feature)
    print(f"Feature: {feature}, Index: {feature_index}")
# Out:
# Feature: Built 1939 or earlier, Index: 5
# Feature: ADHD Percentage (Ever), Index: 37
# Feature: lng, Index: 36
# Feature: ADHD Percentage (Current), Index: 38
# Feature: ADHD Meds or BT, Index: 41
# Feature: lat, Index: 35
# Feature: ADHD Behavior Treatment(%), Index: 39
# Feature: ADHD Medication(%), Index: 40
# Feature: Built 2000 to 2019, Index: 1
# Feature: Built 1980 to 1999, Index: 2

# %% [markdown]
# # Visualization with Extra Trees

# %%
# Scatter plot of predicted versus actual values (Non-zero actual values)
non_zero_indices = y_val != 0  # Get indices where actual values are not zero

plt.figure(figsize=(8, 6))
plt.scatter(y_val[non_zero_indices], y_pred_extra_trees[non_zero_indices], alpha=0.5)
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], color='red', linestyle='--') 
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values (Non-zero Actual Values) using Extra Trees")
plt.show()

# Scatter plot of predicted versus actual values (Zero actual values)
zero_indices = y_val == 0  # Get indices where actual values are zero

plt.figure(figsize=(8, 6))
plt.scatter(y_val[zero_indices], y_pred_extra_trees[zero_indices], alpha=0.5)
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], color='red', linestyle='--') 
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values (Zero Actual Values) using Extra Trees")
plt.show()

# %%
# Residual plot (Non-zero actual values)
residuals_non_zero = y_val[non_zero_indices] - y_pred_extra_trees[non_zero_indices]

plt.figure(figsize=(8, 6))
plt.scatter(y_pred_extra_trees[non_zero_indices], residuals_non_zero, alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')  # Zero residual line
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot (Non-zero Actual Values) using Extra Trees")
plt.show()

# Residual plot (Zero actual values)
residuals_zero = y_val[zero_indices] - y_pred_extra_trees[zero_indices]

plt.figure(figsize=(8, 6))
plt.scatter(y_pred_extra_trees[zero_indices], residuals_zero, alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')  # Zero residual line
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot (Zero Actual Values) using Extra Trees")
plt.show()

# %%
# Select top 10 features
top_10_features = feature_importance_extra_trees_df.head(10)

# Create the bar chart
plt.figure(figsize=(12, 8))  # Adjust figure size as needed
plt.barh(top_10_features['Feature'], top_10_features['Importance'])
plt.xlabel("Importance")
plt.ylabel("Features")
plt.title("Top 10 Feature Importances using Extra Trees")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model training with Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# Define parameter grid
param_grid = {
    'n_estimators': np.arange(100,500,50),
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]
}

# Create Random Forest Regressor object
rf_regressor = RandomForestRegressor(random_state=42)

# Create RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=rf_regressor,
    param_distributions=param_grid,
    n_iter=50,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

# Fit the model to the scaled training data
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=   2.9s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=   2.7s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=   2.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   4.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   4.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   4.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   4.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   4.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   1.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   1.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   1.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   1.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.4s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=   2.6s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=   2.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   1.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.8s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.8s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.7s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.7s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=350; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   1.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   1.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   1.6s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   1.5s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   1.6s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   1.6s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   1.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.6s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=450; total time=   4.7s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=450; total time=   4.9s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=450; total time=   4.7s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=450; total time=   4.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   1.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   1.7s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=450; total time=   4.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   1.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   1.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=350; total time=   4.3s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=350; total time=   4.4s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=350; total time=   4.4s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=350; total time=   4.6s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=350; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   2.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   0.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   0.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=450; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   0.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=   2.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=   3.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=   3.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=   3.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=   3.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=350; total time=   0.8s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=350; total time=   0.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   1.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=450; total time=   1.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=450; total time=   1.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=450; total time=   1.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=450; total time=   1.1s
# [CV] END max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=450; total time=   1.1s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.8s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.8s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=450; total time=   3.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=450; total time=   3.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=450; total time=   3.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=450; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=450; total time=   3.4s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=10, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.7s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'max_depth': [None, 5, 10, 15],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': array([100, 150, 200, 250, 300, 350, 400, 450])},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Get the best parameters
best_params_rf = random_search.best_params_
print("Best Parameters:", best_params_rf)

# Get the best model
best_model_rf = random_search.best_estimator_

# Make predictions
y_pred_rf = best_model_rf.predict(X_val)

# Evaluate MSE and R2
mse_rf = mean_squared_error(y_val, y_pred_rf)
r2_rf = r2_score(y_val, y_pred_rf)

# Calculate RMSE
rmse_rf = np.sqrt(mse_rf)

print(f"Random Forest - Root Mean Squared Error: {rmse_rf}")
print(f"Random Forest - R-squared: {r2_rf}")
# Out:
# Best Parameters: {'n_estimators': np.int64(450), 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 10}
# Random Forest - Root Mean Squared Error: 1.749323329422262
# Random Forest - R-squared: 0.35943118594448664

# %%
# Get feature importance
feature_importance_rf = best_model_rf.feature_importances_

# Create df for feature importance
feature_importance_rf_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance_rf
})

# Sort by importance
feature_importance_rf_df = feature_importance_rf_df.sort_values(by='Importance', ascending=False)

# Select top 10 features
top_10_features_rf = feature_importance_rf_df['Feature'].head(10).tolist()

# Print feature names and indices for verification
for feature in top_10_features_rf:
    feature_index = X_train.columns.get_loc(feature)
    print(f"Feature: {feature}, Index: {feature_index}")
# Out:
# Feature: Built 1939 or earlier, Index: 5
# Feature: lng, Index: 36
# Feature: lat, Index: 35
# Feature: ADHD Meds or BT, Index: 41
# Feature: ADHD Behavior Treatment(%), Index: 39
# Feature: ADHD Percentage (Ever), Index: 37
# Feature: Lacking complete kitchen facilities, Index: 6
# Feature: 65 years and over:!!No health insurance coverage, Index: 12
# Feature: Under 19 years:!!No health insurance coverage, Index: 10
# Feature: Built 2020 or later, Index: 0

# %% [markdown]
# # Model training with XGboost

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# Define XGBoost regressor
xgb_regressor = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Define the parameter grid
param_grid_xgb = {
    'n_estimators': [100, 200, 300, 400, 500],
    'learning_rate': [0.001, 0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7, 9],
    'subsample': [0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'gamma': [0, 0.1, 0.2],
    'min_child_weight': [1, 3, 5],
    'reg_alpha': [0, 0.1, 1],
    'reg_lambda': [0, 0.1, 1]
}

# Create RandomizedSearchCV object
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_regressor,
    param_distributions=param_grid_xgb,
    n_iter=20,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

# Fit the model
random_search_xgb.fit(X_train, y_train)

# Get best params and best model
best_params_xgb = random_search_xgb.best_params_
best_xgb_model = random_search_xgb.best_estimator_
print("Best XGBoost Parameters:", best_params_xgb)

# Make predictions on validation set
y_pred_xgb = best_xgb_model.predict(X_val)

# Evaluate the model
mse_xgb = mean_squared_error(y_val, y_pred_xgb)
r2_xgb = r2_score(y_val, y_pred_xgb)

# Calculate RMSE
rmse_xgb = np.sqrt(mse_xgb)

print(f"XGBoost - Root Mean Squared Error: {rmse_xgb}")
print(f"XGBoost - R-squared: {r2_xgb}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.1, reg_lambda=1, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.001, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.001, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.001, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.001, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.001, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s[CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
#
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=1.0; total time=   0.3s
# Best XGBoost Parameters: {'subsample': 0.9, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_estimators': 500, 'min_child_weight': 3, 'max_depth': 5, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.9}
# XGBoost - Root Mean Squared Error: 1.769810037002745
# XGBoost - R-squared: 0.344339647666674

# %%
# Get feature importance
feature_importance_xgb = best_xgb_model.feature_importances_

# Create df for feature importance
feature_importance_xgb_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance_xgb
})

# Sort by importance
feature_importance_xgb_df = feature_importance_xgb_df.sort_values(by='Importance', ascending=False)

# Select top 10 features
top_10_features_xgb = feature_importance_xgb_df['Feature'].head(10).tolist()

# Print feature names and indices for verification
for feature in top_10_features_xgb:
    feature_index = X_train.columns.get_loc(feature)
    print(f"Feature: {feature}, Index: {feature_index}")
# Out:
# Feature: Built 1939 or earlier, Index: 5
# Feature: ADHD Behavior Treatment(%), Index: 39
# Feature: ADHD Percentage (Ever), Index: 37
# Feature: ADHD Meds or BT, Index: 41
# Feature: lat, Index: 35
# Feature: lng, Index: 36
# Feature: ADHD Medication(%), Index: 40
# Feature: Under 19 years:!!With health insurance coverage, Index: 9
# Feature: Income in the past 12 months at or above poverty level:!!65 years and over, Index: 34
# Feature: ADHD Percentage (Current), Index: 38

# %% [markdown]
# # Visualizations with XGBoost

# %%
# Scatter plot of predicted versus actual values (Non-zero actual values)
non_zero_indices = y_val != 0  # Get indices where actual values are not zero

plt.figure(figsize=(8, 6))
plt.scatter(y_val[non_zero_indices], y_pred_xgb[non_zero_indices], alpha=0.5)
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], color='red', linestyle='--') 
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values (Non-zero Actual Values) using XGBoost")
plt.show()

# Scatter plot of predicted versus actual values (Zero actual values)
zero_indices = y_val == 0  # Get indices where actual values are zero

plt.figure(figsize=(8, 6))
plt.scatter(y_val[zero_indices], y_pred_xgb[zero_indices], alpha=0.5)
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], color='red', linestyle='--') 
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values (Zero Actual Values) using XGBoost")
plt.show()

# %%
# Residual plot (Non-zero actual values)
residuals_non_zero = y_val[non_zero_indices] - y_pred_xgb[non_zero_indices]

plt.figure(figsize=(8, 6))
plt.scatter(y_pred_xgb[non_zero_indices], residuals_non_zero, alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')  # Zero residual line
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot (Non-zero Actual Values) using XGboost")
plt.show()

# Residual plot (Zero actual values)
residuals_zero = y_val[zero_indices] - y_pred_xgb[zero_indices]

plt.figure(figsize=(8, 6))
plt.scatter(y_pred_xgb[zero_indices], residuals_zero, alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')  # Zero residual line
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot (Zero Actual Values) using XGboost")
plt.show()

# %%
# Bar chart of top 10 features
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_xgb_df['Feature'].head(10), feature_importance_xgb_df['Importance'].head(10)) #Changed this line
plt.xlabel("Importance")
plt.ylabel("Features")
plt.title("Feature Importance for top 10 features using XGboost")
plt.show()
